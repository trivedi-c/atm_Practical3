# %% [markdown]
# <img src='./img/oean_atmos_banner.png' alt='banner' align='right' width='60%'></img>

# %% [markdown]
# <hr>

# %% [markdown]
# # COPERNICUS MARINE OCEANCOLOUR - How to visualize maps and time-series of chlorophyll

# %% [markdown]
# ## Table of contents
# - [1. Introduction](#1.-Introduction)
# - [2. About the data](#2.-About-the-data)
#     - [2.1. Example 1](#2.1.-First-example)
#     - [2.2. Examples 2](#2.2.-Second-example)
#     - [2.3. Download data with motuclient](#2.3.-Download-data-with-motuclient)
# - [3. Exercise n.1: Plot of maps](#3.-Exercise-n.1:-Plot-of-maps)
# - [4. Exercise n.2: Plot of time series](#4.-Exercise-n.2:-Plot-of-Time-series)

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# This python notebook contains two examples of visualization of the chlorophyll (Chl) products for the Black sea. The first example will show how to make a map of Chlorophyll data using the Near Real Time daily interpolated chlorophyll field. The second example will show how to make  plot of two locations in the basin of the reprocessed Chlorophyll  daily time series   and of the monthly averages.

# %% [markdown]
# ## 2. About the data

# %% [markdown]
# ### 2.1. First example

# %% [markdown]
# #### 2.1.1. Model description
#
# #### The first example is based on the product: [OCEANCOLOUR_BS_CHL_L4_NRT_OBSERVATIONS_009_045](https://resources.marine.copernicus.eu/?option=com_csw&task=results?option=com_csw&view=details&product_id=OCEANCOLOUR_BS_CHL_L4_NRT_OBSERVATIONS_009_045)

# %% [markdown]
# The Global Ocean Satellite monitoring and marine ecosystem study group (GOS) of the Italian National Research Council (CNR), in Rome, distributes Level-4 product - both monthly averaged datasets and the daily interpolated chlorophyll field with no data voids (excluding OLCI dataset), all at 1 km spatial resolution starting from the multi-sensor (MODIS-Aqua, NPP-VIIRS, Sentinel3-OLCI) and single sensor Sentinel3-OLCI Level-3 chlorophyll concentration.
#
# The chlorophyll (Chl) product is obtained by the combination of two different regional algorithms. The first is a band-ratio algorithm (Zibordi et al., 2015) that computes Chl as a function of the slope of Rrs values at two wavelengths (490 and 555 nm). The second one is a Multilayer Perceptron (MLP) neural net based on Rrs values at three individual wavelengths (490, 510 and 555 nm) that features interpolation capabilities helpful to fit data non-linearities. The merging scheme (Kajiyama et al., 2018) has been designed to use the band ratio algorithm and the MLP neural net in waters exhibiting lower and higher optical complexity, respectively. The interpolated gap-free Level-4 Chlorophyll concentration is estimated by means of a modified version of the DINEOF algorithm by GOS (Volpe et al., 2018). DINEOF is an iterative procedure in which Empirical Orthogonal Functions are used to reconstruct the entire field domain. As first guess, it uses the SeaWiFS-derived daily climatological values at missing pixels and satellite observations at valid pixels.
#
# The other L4 datasets (monthly) are the time averages of the L3 fields (including standard deviation and the number of observations). These products quantify the average chlorophyll content of the surface layer as defined by the first optical depth.

# %% [markdown]
# #### 2.1.2. Get more info on the product
#
# 1. You can find info on this product and access to the download services in the [dedicated Product Page on Copernicus Marine (CMEMS) Web portal](https://resources.marine.copernicus.eu/?option=com_csw&task=results?option=com_csw&view=details&product_id=OCEANCOLOUR_BS_CHL_L4_NRT_OBSERVATIONS_009_045)
# <br>
# 2. For **detailed information** about the product, please consult the **document**: [Product User Manual (PUM)](./docs/ProductUserManuals/CMEMS-OC-PUM-009-ALL.pdf)
# <br>
# 3. For information about **the quality and validation** of the product, please consult the **document**: [Quality Information Document (QUID)](./docs/QualityInformationDocuments/CMEMS-OC-QUID-009-038to045-071-073-078-079-095-096.pdf)

# %% [markdown]
# #### 2.1.3. Parameters used for downloading data
#
# | Parameter | Value |
# | :--- | :---|
# | **Product** | OCEANCOLOUR_BS_CHL_L4_NRT_OBSERVATIONS_009_045 |
# | **Datasets** | dataset-oc-bs-chl-multi-l4-interp_1km_daily-rt-v02 |
# | **Frequency** | daily |
# | **Lat min** | 40 |
# | **Lat max** | 48 |
# | **Lon min** | 26.5 |
# | **Lon max** | 42 |
# | **Timesteps** | from  2020-05-05T00:00 to 2020-05-06T00:00 |
# | **Variables** | CHL |
# | **Service for downloading** | SUBSETTER |
# | **Files total dimension** | 7 MB |

# %% [markdown]
# ### 2.2. Second example

# %% [markdown]
# #### 2.2.1. Model description
# #### The second example is based on the product:  [OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071 ](https://resources.marine.copernicus.eu/?option=com_csw&task=results?option=com_csw&view=details&product_id=OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071)

# %% [markdown]
# The Global Ocean Satellite monitoring and marine ecosystem study group (GOS) of the Italian National Research Council (CNR), in Rome, distributes surface chlorophyll concentration (mg m-3, 1 km resolution) estimated via regional algorithm (BSAlg) applied over the Remote Sensing Reflectance (Rrs) spectra provided by the Plymouth Marine Laboratory using an ad-hoc configuration of the ESA-CCI processor for CMEMS at high resolution. This version has the qualification of the fully reprocessed time series (1997-2018) based on CCIv4 that incorporates NASA R2018.0 reprocessing for MODIS-AQUA, SeaWiFS and VIIRS, and POLYMER atmospheric correction for MERIS R2012.0. These Rrs spectra are the result of state-of-the-art algorithms for multi-sensor merging.
#
# BSAlg is obtained from the combination of two different regional algorithms. The first is a band-ratio algorithm (Zibordi et al., 2015) that computes Chl as a function of the slope of Rrs values at two wavelengths (490 and 555 nm) using a polynomial regression that captures the overall data trend. The second one is a Multilayer Perceptron (MLP) neural net based on Rrs values at three individual wavelengths (490, 510 and 555 nm) that features interpolation capabilities helpful to fit data nonlinearities. The merging scheme (Kajiyama et al., 2018) has been designed to use the band-ratio algorithm and the MLP neural net in waters exhibiting lower and higher optical complexity, respectively.

# %% [markdown]
# #### 2.2.2. Get more info on the product
#
# 1. You can find info on this product and access to the download services in the [dedicated Product Page on Copernicus Marine (CMEMS) Web portal](https://resources.marine.copernicus.eu/?option=com_csw&task=results?option=com_csw&view=details&product_id=OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071)
# <br>
# 2. For **detailed information** about the product, please consult the **document**: [Product User Manual (PUM)](./docs/ProductUserManuals/CMEMS-OC-PUM-009-ALL.pdf)
# <br>
# 3. For information about **the quality and validation** of the product, please consult the **document**: [Quality Information Document (QUID)](./docs/QualityInformationDocuments/CMEMS-OC-QUID-009-038to045-071-073-078-079-095-096.pdf)

# %% [markdown]
# #### 2.2.3. Parameters used for downloading data (two datasets)
#
# | Parameter | Value |
# | :--- | :---|
# | **Product** | OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071 |
# | **Datasets** | dataset-oc-bs-chl-multi-l4-interp_1km_daily-rt-v02 |
# | **Frequency** | daily |
# | **Lat min** | 28.3 and 30.0 |
# | **Lat max** | 28.4 and 30.1  |
# | **Lon min** | 43.0 and 43.0 |
# | **Lon max** | 43.1 and 43.1 |
# | **Timesteps** | both from  1997-9-4T00:00 to 2018-12-31T00:00 |
# | **Variables** | CHL |
# | **Service for downloading** | SUBSETTER |
# | **Files total dimension** | 2.8 MB each |

# %% [markdown]
# ### 2.3. Download data with motuclient

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <b>Get the CMEMS User credentials</b>
# <hr>
# Before being able to run the following exercises on yout PC and to download the needed data, please be sure to have by your CMEMS User credentials. Otherwise please get them <a href="http://marine.copernicus.eu/services-portfolio/register-now/" target="_blank">here</a>.

# %% [markdown]
# #### Download motuclient

# %% [markdown]
# Data can be alternatively downloaded with **motuclient**, a multiplatform python script to automate extraction of information from the Marine Copernicus portal. To install motuclient:

# %% [markdown]
# ```
# !pip install motuclient
# ```

# %% [markdown]
# To get more info on motuclient visit the related [web page](https://marine.copernicus.eu/faq/what-are-the-motu-and-python-requirements/#motu-client).

# %% [markdown]
# #### First example

# %% [markdown]
# You'll be able to download data with the following command line that you have to copy to another cell for being execute (**NOTE:** don't forget to set username and password):

# %% [markdown]
# ```
# !python -m motuclient --motu http://nrt.cmems-du.eu/motu-web/Motu \
#     --service-id OCEANCOLOUR_BS_CHL_L4_NRT_OBSERVATIONS_009_045-TDS \
#     --product-id dataset-oc-bs-chl-multi-l4-interp_1km_daily-rt-v02 \
#     --longitude-min 26.5 --longitude-max 42.000640869140625 \
#     --latitude-min 40 --latitude-max 48.000038146972656 \
#     --date-min "2020-05-05 00:00:00" --date-max "2020-05-06 00:00:00" --variable CHL \
#     --out-dir ./data --out-name 07-04-A.nc --user <USERNAME> --pwd <PASSWORD>
# ```

# %% [markdown]
# Insert the download command below, if needed:

# %% [markdown]
# To check if the file has been correctly downloaded:

# %%
import os
for filename in os.listdir("data"):
    print(filename)
# Out:
# .DS_Store
# 07-04-A.nc
# 07-04-B.nc
# 07-04-C.nc

# %% [markdown]
# #### Second example

# %% [markdown]
# You'll be able to download data with the following command lines that you have to copy to another cell for being execute (**NOTE:** don't forget to set username and password):

# %% [markdown]
# ```
# !python -m motuclient --motu http://my.cmems-du.eu/motu-web/Motu \
#     --service-id OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071-TDS \
#     --product-id dataset-oc-bs-chl-multi_cci-l3-chl_1km_daily-rep-v02 \
#     --longitude-min 28.3 --longitude-max 28.4 \
#     --latitude-min 43.0 --latitude-max 43.1 \
#     --date-min "1997-9-4 00:00:00" --date-max "2018-12-31 00:00:00" \
#     --variable CHL \
#     --out-dir ./data --out-name "07-04-B.nc" --user <USERNAME> --pwd <PASSWORD>
# ```

# %% [markdown]
# Insert the download command below, if needed:

# %% [markdown]
# ```
# !python -m motuclient --motu http://my.cmems-du.eu/motu-web/Motu \
#     --service-id OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071-TDS \
#     --product-id dataset-oc-bs-chl-multi_cci-l3-chl_1km_daily-rep-v02 \
#     --longitude-min 33.0 --longitude-max 33.1 \
#     --latitude-min 43.0 --latitude-max 43.1 \
#     --date-min "1997-9-4 00:00:00" --date-max "2018-12-31 00:00:00" \
#     --variable CHL \
#     --out-dir ./data --out-name "07-04-C.nc" --user <USERNAME> --pwd <PASSWORD>
# ```

# %% [markdown]
# Insert the download command below, if needed:

# %% [markdown]
# To check if the file has been correctly downloaded:

# %%
import os
for filename in os.listdir("data"):
    print(filename)
# Out:
# .DS_Store
# 07-04-A.nc
# 07-04-B.nc
# 07-04-C.nc

# %% [markdown]
# ## 3. Exercise n.1: Plot of maps

# %% [markdown]
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# #### In this exercise we will see how to plot maps of chlorophyll for the area of Black Sea

# %% [markdown]
# ### 3.1. Required modules

# %% [markdown]
# | Module name | Description |
# | :--- | :---|
# | **os** | [ Miscellaneous operating system interfaces](https://docs.python.org/3.7/library/os.html) for managing paths, creating directories,... |
# | **numpy** | [NumPy](https://numpy.org/) is the fundamental package for scientific computing with Python and for managing ND-arrays |
# | **xarray** | [Xarray](http://xarray.pydata.org/en/stable/) introduces labels in the form of dimensions, coordinates and attributes on top of raw NumPy-like arrays, which allows for a more intuitive, more concise, and less error-prone developer experience. |
# | **matplotlib** |[Matplotlib](https://matplotlib.org/) is a Python 2D plotting library which produces publication quality figures |
# | **basemap** |[The matplotlib basemap toolkit](https://matplotlib.org/basemap/) is a library for plotting 2D data on maps in Python. |
# | **datetime** |[The datetime module](https://docs.python.org/3.8/library/datetime.html) supplies classes for manipulating dates and times in both simple and complex ways. |
# | **pandas** |[pandas](https://pandas.pydata.org/) is a library providing high-performance, easy-to-use data structures and data analysis tools for Python |

# %% [markdown]
# ### 3.2. Import the modules

# %% [markdown]
# Before going on, since we are in Jupyter Notebook, we need to set the environment in order to properly load some of the required libraries.

# %%
import os

# %% [markdown]
# To avoid the warning messages during the execution and installation process, at first remove them:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import datetime
import pandas
from matplotlib.colors import LogNorm

# %% [markdown]
# *Don't change the following constants, which define the training and the notebook codes*:

# %%
REGION_CODE = "07"
NB_CODE = "04"

# %% [markdown]
# **checkDir**: function for creating a path, if needed

# %%
def checkDir(outPath):
    if not os.path.exists(outPath):
        os.makedirs(outPath)

# %% [markdown]
# **getRangeIndexes**: function for getting the indexes of the array *arr* between the *var_min* and *var_max* values:

# %%
def getRangeIndexes(arr, var_min, var_max):
    return np.where((arr >= var_min) & (arr <= var_max))[0]

# %% [markdown]
# Set the paths:

# %%
# Path for netcdf files
data_path = './data'
# Path for the output files (images, etc)
out_path = './out/'+REGION_CODE+'-'+NB_CODE

# %% [markdown]
# Check the current directories:

# %%
for filename in os.listdir():
    print(filename)
# Out:
# .DS_Store
# out
# docs
# 07-04-OC_old.ipynb
# img
# 07-04-OC.ipynb
# .ipynb_checkpoints
# data

# %%
# Create directories
checkDir(data_path)
checkDir(out_path)

# %% [markdown]
# Check if the new directories have been created and if the data files are available:

# %%
for path in [data_path, out_path]:
    if os.path.isdir(path):
        print(path)
# Out:
# ./data
# ./out/07-04

# %%
for filename in os.listdir(data_path):
    print(filename)
# Out:
# .DS_Store
# 07-04-A.nc
# 07-04-B.nc
# 07-04-C.nc

# %% [markdown]
# ### 3.3. Access the data

# %%
# Input netcdf file
oc_f = "07-04-A.nc"
 
# Build the complete nc path
oc_nc = os.path.join(data_path, oc_f)

# %%
# Open the nc dataset
oc_ds = xr.open_dataset(oc_nc)

# %% [markdown]
# #### Get info about the dataset

# %%
oc_ds.info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:  (lat: 790, lon: 1101, time: 2)
# Coordinates:
#   * time     (time) object 2020-05-05 00:00:00 2020-05-06 00:00:00
#   * lat      (lat) float32 40.0 40.01014 40.02028 ... 47.97976 47.9899 48.00004
#   * lon      (lon) float32 26.5 26.514091 26.528183 ... 41.98655 42.00064
# Data variables:
#     CHL      (time, lat, lon) float32 ...
# Attributes:
#     references:              1) Zibordi, G., F. Mélin, J.-F. Berthon, and M....
#     product_level:           L4
#     parameter_code:          CHL
#     parameter:               chlorophyll-a concentration
#     comment:
#     start_date:              2020-05-10
#     stop_date:               2020-05-10
#     creation_date:           Mon May 11 2020
#     creation_time:           04:05:24 UTC
#     westernmost_longitude:   26.5
#     easternmost_longitude:   42.0
#     southernmost_latitude:   40.0
#     northernmost_latitude:   48.0
#     grid_resolution:          1 Km
#     days_in_the_future:       1
#     days_in_the_past:         10
#     st_location:              0  0
#     contact:                 technical@gos.artov.isac.cnr.it
#     netcdf_version:          v4
#     grid_mapping:            Equirectangular
#     software_name:           GOS Processing chain
#     history:
#     source:                  surface observation
#     start_time:              08:00:00 UTC
#     stop_time:               14:00:00 UTC
#     file_quality_index:      0
#     citation:
#     distribution_statement:  See CMEMS Data License
#     naming_authority:        CMEMS
#     cmems_production_unit:   OC-CNR-ROMA-IT
#     institution:             CNR-GOS
#     software_version:        v3.0
#     site_name:               BS
#     product_version:         v02QL
#     Conventions:             CF-1.4
#     title:                   dataset-oc-bs-chl-multi-l4-interp_1km_daily-rt-v02
#     cmems_product_id:        OCEANCOLOUR_BS_CHL_L4_NRT_OBSERVATIONS_009_045
#     platform:                Aqua,Suomi-NPP
#     sensor_name:             MODISA,VIIRSN
#     sensor:                  MODISA Moderate Resolution Imaging Spectroradiom...
#     source_files:            X2020122-chl-bs-hr.nc X2020123-chl-bs-hr.nc X202...
#     History:                 Translated to CF-1.0 Conventions by Netcdf-Java ...
#     geospatial_lat_min:      40.0
#     geospatial_lat_max:      48.000038146972656
#     geospatial_lon_min:      26.5
#     geospatial_lon_max:      42.000640869140625>

# %% [markdown]
# And about the variables:

# %%
oc_ds.data_vars
# Out:
# Data variables:
#     CHL      (time, lat, lon) float32 ...

# %% [markdown]
# ... the coordinates:

# %%
oc_ds.coords
# Out:
# Coordinates:
#   * time     (time) object 2020-05-05 00:00:00 2020-05-06 00:00:00
#   * lat      (lat) float32 40.0 40.01014 40.02028 ... 47.97976 47.9899 48.00004
#   * lon      (lon) float32 26.5 26.514091 26.528183 ... 41.98655 42.00064

# %% [markdown]
# ### 3.4. Set the configuration

# %%
# Set the coordinate names (used later for accessing the data)
lon_name = "lon"
lat_name = "lat"
time_name = "time"

# %%
# Set the variable names
var_name = "CHL" # chlorophyll

# %% [markdown]
# ### 3.5. Plot the variables

# %% [markdown]
# #### Configure the variables for the plots

# %%
# Data to plot
var_sel = oc_ds[var_name]

# --- Set up the arrays of coordinates for the selected dataset ---
# 
lats = var_sel[lat_name]
lons = var_sel[lon_name]
times = var_sel[time_name]
    
# --- Set the area: choose the min and max values for the coordinates ---
# (and comment with the symbol # the unnecessary ones!):                                                               
                                                                 
# # Set lat-lon limits - CUSTOM:  focus on DANUBIUS
#lon_min = 28
#lon_max = 31.5
#lat_min = 43.5
#lat_max = 47

# Set lat-lon limits - FULL AREA
lat_min = lats.min()
lat_max = lats.max()
lon_min = lons.min()
lon_max = lons.max()

# set start and end date
start_date = times.min()
end_date = times.max()

# Set the variable min and max values for the plot and the colorbar (otherwise assign None):
# min_value, max_value = None, None
min_value, max_value = 0, 6.5

# -- Set the time period --- 
plot_date = np.datetime64(datetime.datetime(2020,5,5,0))

# %%
# Plot configuration
width_inch = 16
height_inch = 8

# Map configuration
map_config = { 
#     "projection": "merc",
    "llcrnrlat": lat_min,
    "llcrnrlon": lon_min,
    "urcrnrlat": lat_max,
    "urcrnrlon": lon_max,
    "resolution": 'i',
    "epsg": 4326
}

# Axes labels
fontsize = 14
xlabel = 'longitude [deg]'
ylabel = 'latitude [deg]'
xlabelpad = 30
ylabelpad = 60

# Colorbar configuration
cmap = "Spectral_r"
cbar_position = "right"

title_fontstyle = {
    "fontsize": "14",
    "fontstyle": "italic",
    "fontweight": "bold",
    "pad": 30
}

label_fontstyle = {
    "fontsize": "12",
    "labelpad": 30
}

# Set the coordinates indexes
lat_indexes = getRangeIndexes(lats, lat_min, lat_max)
lon_indexes = getRangeIndexes(lons, lon_min, lon_max)
time_indexes = getRangeIndexes(times, start_date, end_date)

# Get the selected coordinates:
lats_sel = lats[lat_indexes]
lons_sel = lons[lon_indexes]

# Get the timestep
timestep = np.datetime_as_string(plot_date,'h')

# Get the data
data = var_sel[time_indexes[0], lat_indexes, lon_indexes]

# Initialise the figure
plt.figure(figsize=(width_inch, height_inch))
map = Basemap(**map_config)

## imshow the data
min_value = data.min() if min_value is None else min_value
max_value = data.max() if max_value is None else max_value

# # imshow with linear range
# imshow= map.imshow(data, vmin=min_value, vmax=max_value, cmap=cmap)

# imshow with log range
# min fixed 
min_value=0.1
imshow= map.imshow(data, vmin=min_value, vmax=max_value, cmap=cmap, norm=LogNorm())

## draw meridians and parallels
step_lat = float((lat_max - lat_min) / 5)
step_lon = float((lon_max - lon_min) / 5)
parallels = np.arange(lat_min, lat_max, step_lat)
meridians = np.arange(lon_min, lon_max, step_lon) 
map.drawmeridians(meridians, labels=[0,0,0,1], fmt="%2.1f")
map.drawparallels(parallels, labels=[1,0,0,0], fmt="%2.1f")

## draw colorbar
map.colorbar(imshow, cbar_position)



## draw countries...
map.drawcountries(linewidth=0.25, color='olive')
map.fillcontinents(color='lightgray',lake_color='aqua')

# set title
title_sel = data.long_name
var_str = "{} [{}]".format(title_sel, data.units)
title = ' - '.join((var_str, timestep))
    
## draw title and axes labels
plt.title(title, **title_fontstyle)
plt.xlabel(xlabel, labelpad=xlabelpad, fontsize=12)
plt.ylabel(ylabel, labelpad=ylabelpad, fontsize=12)    
    
# output file
output_file = os.path.join(out_path,title.translate(str.maketrans(' ,','__'))) + ".png"


# save the output file
plt.savefig(output_file)
plt.show()
plt.close()

# %% [markdown]
# If you can't see easily the maps, you can disable the scrolling.
# Choose the previous cell (the one with the maps), then select in the menu: **Cell &rarr; Current Output &rarr; Toggle Scrolling**

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### LET'S TRY: Change the plot!
#
# If you want, you can change the above plot.
#
# For example, you could:
# - change the area (remember to change the *skip_points* too!)
# - change the min/max values for the chosen variable

# %% [markdown]
# ***

# %% [markdown]
# ## 4. Exercise n.2: Plot of Time series
# [Go back to the "Table of contents"](#Table-of-contents)

# %% [markdown]
# In this exercise we will see how to plot the time series of chlorophyll for two small regions in the Black Sea. The first region is located on the shelf, the second in the middle of the basin

# %% [markdown]
# ### 4.1. Required modules

# %% [markdown]
# The list of modules required to run this exercise is reported in the table below:

# %% [markdown]
# | Module name | Description |
# | :--- | :---|
# | **os** | [ Miscellaneous operating system interfaces](https://docs.python.org/3.7/library/os.html) for managing paths, creating directories,... |
# | **numpy** | [NumPy](https://numpy.org/) is the fundamental package for scientific computing with Python and for managing ND-arrays |
# | **xarray** | [Xarray](http://xarray.pydata.org/en/stable/) introduces labels in the form of dimensions, coordinates and attributes on top of raw NumPy-like arrays, which allows for a more intuitive, more concise, and less error-prone developer experience. |
# | **matplotlib** |[Matplotlib](https://matplotlib.org/) is a Python 2D plotting library which produces publication quality figures |
# | **basemap** |[The matplotlib basemap toolkit](https://matplotlib.org/basemap/) is a library for plotting 2D data on maps in Python. |
# | **datetime** |[The datetime module](https://docs.python.org/3.8/library/datetime.html) supplies classes for manipulating dates and times in both simple and complex ways. |
# | **pandas** |[pandas](https://pandas.pydata.org/) is a library providing high-performance, easy-to-use data structures and data analysis tools for Python |

# %% [markdown]
# ### 4.2. Import the modules

# %% [markdown]
# Before going on, since we are in Jupyter Notebook, we need to set the environment in order to properly load some of the required libraries.

# %%
import os

# %% [markdown]
# To avoid the warning messages during the execution and installation process, at first remove them:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import datetime
import pandas as pd
import matplotlib.dates as mdates

# %% [markdown]
# *Don't change the following constants, which define the training and the notebook codes*:

# %%
REGION_CODE = "07"
NB_CODE = "04"

# %% [markdown]
# **checkDir**: function for creating a path, if needed

# %%
def checkDir(outPath):
    if not os.path.exists(outPath):
        os.makedirs(outPath)

# %% [markdown]
# **getRangeIndexes**: function for getting the indexes of the array *arr* between the *var_min* and *var_max* values:

# %%
def getRangeIndexes(arr, var_min, var_max):
    return np.where((arr >= var_min) & (arr <= var_max))[0]

# %% [markdown]
# Set the paths:

# %%
# Path for netcdf files
data_path = './data'

# Path for the output files (images, etc)
out_path = './out/'+REGION_CODE+'-'+NB_CODE

# %% [markdown]
# ### 4.3. Access the data

# %%
# Input netcdf file
chl_f1 = "07-04-B.nc"
chl_f2 = "07-04-C.nc"
 
# Build the complete nc path
chl_nc1 = os.path.join(data_path, chl_f1)
chl_nc2 = os.path.join(data_path, chl_f2)

# %%
# Open the nc datasets
chl_ds1 = xr.open_dataset(chl_nc1)
chl_ds2 = xr.open_dataset(chl_nc2)

# %% [markdown]
# #### Get info about the datasets

# %%
chl_ds1.info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:  (lat: 11, lon: 8, time: 7750)
# Coordinates:
#   * time     (time) object 1997-09-04 00:00:00 ... 2018-12-31 00:00:00
#   * lat      (lat) float32 43.00128 43.01142 43.02156 ... 43.092537 43.102676
#   * lon      (lon) float32 28.30371 28.317802 28.331894 ... 28.38826 28.402351
# Data variables:
#     CHL      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:             CF-1.4
#     title:                   dataset-oc-bs-chl-multi_cci-l3-chl_1km_daily-rep...
#     references:              1) Zibordi, G., F. Mélin, J.-F. Berthon, and M....
#     institution:             CNR-GOS
#     contact:                 technical@gos.artov.isac.cnr.it
#     netcdf_version:          v4
#     grid_mapping:            Equirectangular
#     product_level:           L3
#     parameter_code:          CHL
#     parameter:               chlorophyll-a concentration
#     platform:                Orbview-2/SeaStar,Aqua,ENVISAT,NPP
#     sensor_name:             SeaWiFS,MODIS,MERIS,VIIRS
#     sensor:                  Sea-viewing Wide Field-of-view Sensor,Moderate R...
#     software_name:           GOS Processing chain
#     software_version:        v01
#     history:
#     source:                  surface observation
#     comment:
#     start_time:              08:00:00 UTC
#     stop_time:               14:00:00 UTC
#     file_quality_index:      0
#     Citation:
#     naming_authority:        CMEMS
#     distribution_statement:  See CMEMS Data License
#     cmems_product_id:        OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071
#     cmems_production_unit:   OC-CNR-ROMA-IT
#     start_date:              2018-12-31
#     stop_date:               2018-12-31
#     creation_date:           mar giu 18 2019
#     creation_time:           10:06:41 UTC
#     westernmost_longitude:   26.5
#     easternmost_longitude:   42.0
#     southernmost_latitude:   40.0
#     northernmost_latitude:   48.0
#     grid_resolution:          1 Km
#     product_version:         v02
#     site_name:
#     History:                 Translated to CF-1.0 Conventions by Netcdf-Java ...
#     geospatial_lat_min:      43.00128173828125
#     geospatial_lat_max:      43.10267639160156
#     geospatial_lon_min:      28.3037109375
#     geospatial_lon_max:      28.40235137939453>

# %%
chl_ds2.info
# Out:
# <bound method Dataset.info of <xarray.Dataset>
# Dimensions:  (lat: 11, lon: 8, time: 7750)
# Coordinates:
#   * time     (time) object 1997-09-04 00:00:00 ... 2018-12-31 00:00:00
#   * lat      (lat) float32 43.00128 43.01142 43.02156 ... 43.092537 43.102676
#   * lon      (lon) float32 32.996178 33.01027 33.02436 ... 33.080727 33.09482
# Data variables:
#     CHL      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:             CF-1.4
#     title:                   dataset-oc-bs-chl-multi_cci-l3-chl_1km_daily-rep...
#     references:              1) Zibordi, G., F. Mélin, J.-F. Berthon, and M....
#     institution:             CNR-GOS
#     contact:                 technical@gos.artov.isac.cnr.it
#     netcdf_version:          v4
#     grid_mapping:            Equirectangular
#     product_level:           L3
#     parameter_code:          CHL
#     parameter:               chlorophyll-a concentration
#     platform:                Orbview-2/SeaStar,Aqua,ENVISAT,NPP
#     sensor_name:             SeaWiFS,MODIS,MERIS,VIIRS
#     sensor:                  Sea-viewing Wide Field-of-view Sensor,Moderate R...
#     software_name:           GOS Processing chain
#     software_version:        v01
#     history:
#     source:                  surface observation
#     comment:
#     start_time:              08:00:00 UTC
#     stop_time:               14:00:00 UTC
#     file_quality_index:      0
#     Citation:
#     naming_authority:        CMEMS
#     distribution_statement:  See CMEMS Data License
#     cmems_product_id:        OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071
#     cmems_production_unit:   OC-CNR-ROMA-IT
#     start_date:              2018-12-31
#     stop_date:               2018-12-31
#     creation_date:           mar giu 18 2019
#     creation_time:           10:06:41 UTC
#     westernmost_longitude:   26.5
#     easternmost_longitude:   42.0
#     southernmost_latitude:   40.0
#     northernmost_latitude:   48.0
#     grid_resolution:          1 Km
#     product_version:         v02
#     site_name:
#     History:                 Translated to CF-1.0 Conventions by Netcdf-Java ...
#     geospatial_lat_min:      43.00128173828125
#     geospatial_lat_max:      43.10267639160156
#     geospatial_lon_min:      32.996177673339844
#     geospatial_lon_max:      33.094818115234375>

# %% [markdown]
# ### 4.4. Set the configuration

# %%
# Set the variable names (used later for accessing the data)
lon_name = "lon"
lat_name= "lat"
time_name = "time"
chl_name = "CHL"

# %% [markdown]
# ### 4.5. Plot the time series

# %% [markdown]
# #### Choose the points of interest:

# %%
# Set the points of interest
point1 = {'x': 28.33, 'y': 43.02}
point2 = {'x': 33.07, 'y': 43.08}

# %% [markdown]
# #### Extract the dataset for the selected points:

# %%
# Extract the sub-dataset for the first defined point
ds_sel1 = chl_ds1.sel(lat=point1['y'], lon=point1['x'], method='nearest')
ds_sel1
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7750)
# Coordinates:
#   * time     (time) object 1997-09-04 00:00:00 ... 2018-12-31 00:00:00
#     lat      float32 43.02156
#     lon      float32 28.331894
# Data variables:
#     CHL      (time) float32 ...
# Attributes:
#     Conventions:             CF-1.4
#     title:                   dataset-oc-bs-chl-multi_cci-l3-chl_1km_daily-rep...
#     references:              1) Zibordi, G., F. Mélin, J.-F. Berthon, and M....
#     institution:             CNR-GOS
#     contact:                 technical@gos.artov.isac.cnr.it
#     netcdf_version:          v4
#     grid_mapping:            Equirectangular
#     product_level:           L3
#     parameter_code:          CHL
#     parameter:               chlorophyll-a concentration
#     platform:                Orbview-2/SeaStar,Aqua,ENVISAT,NPP
#     sensor_name:             SeaWiFS,MODIS,MERIS,VIIRS
#     sensor:                  Sea-viewing Wide Field-of-view Sensor,Moderate R...
#     software_name:           GOS Processing chain
#     software_version:        v01
#     history:
#     source:                  surface observation
#     comment:
#     start_time:              08:00:00 UTC
#     stop_time:               14:00:00 UTC
#     file_quality_index:      0
#     Citation:
#     naming_authority:        CMEMS
#     distribution_statement:  See CMEMS Data License
#     cmems_product_id:        OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071
#     cmems_production_unit:   OC-CNR-ROMA-IT
#     start_date:              2018-12-31
#     stop_date:               2018-12-31
#     creation_date:           mar giu 18 2019
#     creation_time:           10:06:41 UTC
#     westernmost_longitude:   26.5
#     easternmost_longitude:   42.0
#     southernmost_latitude:   40.0
#     northernmost_latitude:   48.0
#     grid_resolution:          1 Km
#     product_version:         v02
#     site_name:
#     History:                 Translated to CF-1.0 Conventions by Netcdf-Java ...
#     geospatial_lat_min:      43.00128173828125
#     geospatial_lat_max:      43.10267639160156
#     geospatial_lon_min:      28.3037109375
#     geospatial_lon_max:      28.40235137939453

# %%
# Extract the sub-dataset for the second defined point
ds_sel2 = chl_ds2.sel(lat=point2['y'], lon=point2['x'], method='nearest')
ds_sel2
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7750)
# Coordinates:
#   * time     (time) object 1997-09-04 00:00:00 ... 2018-12-31 00:00:00
#     lat      float32 43.082397
#     lon      float32 33.066635
# Data variables:
#     CHL      (time) float32 ...
# Attributes:
#     Conventions:             CF-1.4
#     title:                   dataset-oc-bs-chl-multi_cci-l3-chl_1km_daily-rep...
#     references:              1) Zibordi, G., F. Mélin, J.-F. Berthon, and M....
#     institution:             CNR-GOS
#     contact:                 technical@gos.artov.isac.cnr.it
#     netcdf_version:          v4
#     grid_mapping:            Equirectangular
#     product_level:           L3
#     parameter_code:          CHL
#     parameter:               chlorophyll-a concentration
#     platform:                Orbview-2/SeaStar,Aqua,ENVISAT,NPP
#     sensor_name:             SeaWiFS,MODIS,MERIS,VIIRS
#     sensor:                  Sea-viewing Wide Field-of-view Sensor,Moderate R...
#     software_name:           GOS Processing chain
#     software_version:        v01
#     history:
#     source:                  surface observation
#     comment:
#     start_time:              08:00:00 UTC
#     stop_time:               14:00:00 UTC
#     file_quality_index:      0
#     Citation:
#     naming_authority:        CMEMS
#     distribution_statement:  See CMEMS Data License
#     cmems_product_id:        OCEANCOLOUR_BS_CHL_L3_REP_OBSERVATIONS_009_071
#     cmems_production_unit:   OC-CNR-ROMA-IT
#     start_date:              2018-12-31
#     stop_date:               2018-12-31
#     creation_date:           mar giu 18 2019
#     creation_time:           10:06:41 UTC
#     westernmost_longitude:   26.5
#     easternmost_longitude:   42.0
#     southernmost_latitude:   40.0
#     northernmost_latitude:   48.0
#     grid_resolution:          1 Km
#     product_version:         v02
#     site_name:
#     History:                 Translated to CF-1.0 Conventions by Netcdf-Java ...
#     geospatial_lat_min:      43.00128173828125
#     geospatial_lat_max:      43.10267639160156
#     geospatial_lon_min:      32.996177673339844
#     geospatial_lon_max:      33.094818115234375

# %% [markdown]
# #### Extract the chlorophyll for the selected timeseries:

# %%
# Extract the chlorophyll for the first point
chl_sel1 = ds_sel1[chl_name].round(2)
chl_sel1
# Out:
# <xarray.DataArray 'CHL' (time: 7750)>
# array([nan, nan, nan, ..., nan, nan, nan], dtype=float32)
# Coordinates:
#   * time     (time) object 1997-09-04 00:00:00 ... 2018-12-31 00:00:00
#     lat      float32 43.02156
#     lon      float32 28.331894

# %%
# Extract the chlorophyll for the second point
chl_sel2 = ds_sel2[chl_name].round(2)
chl_sel2
# Out:
# <xarray.DataArray 'CHL' (time: 7750)>
# array([nan, nan, nan, ..., nan, nan, nan], dtype=float32)
# Coordinates:
#   * time     (time) object 1997-09-04 00:00:00 ... 2018-12-31 00:00:00
#     lat      float32 43.082397
#     lon      float32 33.066635

# %% [markdown]
# #### Convert the two datasets into a pandas DataFrame

# %%
# define two labels
fname1 = "CHL (%s, %s)" % (point1["x"], point1["y"])
fname2 = "CHL (%s, %s)" % (point2["x"], point2["y"])

# create dates np.array for the x axis
dates=[]
for i in range(len(chl_sel1.time.values)) : 
    dates.append(np.datetime64(chl_sel1.time.values[i]))
dates= np.array(dates)   

# create a dataframe with data of the first and second points
df = pd.DataFrame({"Dates": dates, 
                    fname1: chl_sel1,
                    fname2: chl_sel2})
# and let’s set the Dates as the DataFrame’s index.
df = df.set_index('Dates')

# %% [markdown]
# #### Have a look at the data

# %%
## print just a section of this dataframe
df[100:200:1]
# Out:
#             CHL (28.33, 43.02)  CHL (33.07, 43.08)
# Dates
# 1997-12-28                 NaN                0.33
# 1997-12-29                 NaN                 NaN
# 1997-12-30                 NaN                 NaN
# 1997-12-31                1.36                 NaN
# 1998-01-01                 NaN                 NaN
# ...                        ...                 ...
# 1998-04-02                 NaN                0.28
# 1998-04-03                 NaN                 NaN
# 1998-04-04                1.23                 NaN
# 1998-04-05                1.22                0.19
# 1998-04-06                 NaN                0.18
#
# [100 rows x 2 columns]

# %%
# print some summary statitics 
df.describe()
# Out:
#        CHL (28.33, 43.02)  CHL (33.07, 43.08)
# count         2740.000000         2429.000000
# mean             1.092690            0.280313
# std              5.112688            0.142379
# min              0.130000            0.070000
# 25%              0.380000            0.180000
# 50%              0.720000            0.240000
# 75%              1.230000            0.340000
# max            260.859985            1.240000

# %% [markdown]
# #### Compute monthly averages

# %%
# to compute monthly averages we will use the DataFrame’s resample() method
# this splits the DatetimeIndex into time bins and groups the data by time bin
# Resample to monthly frequency, aggregating with mean
df_mean = df.resample("M").mean()

# print some summary statitics 
df_mean.describe()
# Out:
#        CHL (28.33, 43.02)  CHL (33.07, 43.08)
# count          256.000000          254.000000
# mean             1.207396            0.326636
# std              2.142834            0.133586
# min              0.176818            0.128750
# 25%              0.606563            0.215733
# 50%              0.888542            0.305625
# 75%              1.353141            0.408750
# max             30.644444            0.845000

# %% [markdown]
# #### Save the data in csv file format

# %%
# save the dataframe to a csv file
fname_table = "chl_data.csv"
output_table =  os.path.join(out_path, fname_table)
df.to_csv(output_table)

# ...then verify if the file exists
if os.path.isfile(output_table):
    print(output_table)
# Out:
# ./out/07-04/chl_data.csv

# %% [markdown]
# #### Plot

# %%
# we will use the location in the panda data frame to define the x-range

# Start and end of the date range to plot
start, end = '1997', '2019'

#start, end = '2014-01', '2018-06'

# prepare the plot 
fig, ax = plt.subplots(figsize=(20,12))



# plot the first column of the pandas dataframe for the daility times series 
ax.plot(df.loc[start:end, fname1],
        linestyle=':', lw=1, 
        marker='o' ,color="tomato",label=fname1+'-Daily')

# add to the plot the second column of the pandas dataframe
ax.plot(df.loc[start:end, fname2],
        linestyle=':', lw=1, 
        marker='o',  color="royalblue",label=fname2+'-Daily')

 
# now plot also the  monthly averages
# comment with # the """ at the start and botton of this section to uncomment it
"""
ax.plot(df_mean.loc[start:end, fname1],
        linestyle='-', lw=3, color="darkred",label=fname1+'-Monthly')
ax.plot(df_mean.loc[start:end, fname2],
        linestyle='-', lw=3,color="darkblue",label=fname2+'-Monthly')
"""

# format the x axis ticks
years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)
#plot.set_xlim(datemin, datemax)
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')

# format the y axis and ticks 
ax.set_ylabel('CHL')
# set the Y on LOG: COMMENT FOR LINEAR RANGE
ax.set_yscale("log")
ax.set_yticks([0.1,1,10])
ax.set_yticklabels(["0.1","1","10"])

# set the grid
ax.grid(True)

# set the legend
ax.legend();

# set title
title = ds_sel1["CHL"].long_name + " in the Black Sea"
ax.set_title(title);

# output file
output_file = os.path.join(out_path,ds_sel1["CHL"].long_name.replace(' ','_')) + ".png"

# save the output file
plt.savefig(output_file)

# plot!
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# <img src='https://i.imgur.com/I4ake6d.jpg' alt='Logo EU Copernicus' align='left' width='40%'></img>
